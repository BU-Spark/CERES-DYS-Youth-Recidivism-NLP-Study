# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel('/Users/n.y.r/Desktop/DYS/Merge_Sheet_Left/merge_without_YLS_3152.xlsx')

# %%
df['Age 1st Arrest'].value_counts()
# Out:
# missing    880
# 15         517
# 14         517
# 13         434
# 16         354
# 12         209
# 17          89
# 11          82
# 10          36
# 9           20
# 8            8
# 18           5
# 20           1
# 19           1
# Name: Age 1st Arrest, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3153 entries, 0 to 3152
# Data columns (total 79 columns):
# Unnamed: 0                              3153 non-null int64
# MID                                     3153 non-null int64
# Age at Discharge                        3153 non-null int64
# Initial Commitment                      3153 non-null object
# Current  Commitment Date                3153 non-null object
# Age at Initial Commit                   3153 non-null int64
# c1yr                                    3153 non-null object
# Age 1st Arrest                          3153 non-null object
# CW at YES start                         3153 non-null object
# Placement at YES                        3153 non-null object
# Sub-placement at YES                    3153 non-null object
# MSO Code                                3153 non-null object
# Recent YLS Norm at Y.E.S.               3153 non-null object
# YES Start Date                          3153 non-null object
# ...

# %%
df['Age 1st Arrest']=df['Age 1st Arrest'].replace('missing',0)

# %%
result=df.groupby('Race (2018 Std.)')['Treatment LOS'].median().tolist()
print (result)
# Out:
# [389.0, 231.0, 214.0, 151.0, 188.0, 177.5, 398.0, 211.0, 96.0, 175.0]

# %%
import seaborn as sns
sns.set(style="white")

# Load the example mpg dataset


# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="Race (2018 Std.)", y='Treatment LOS', hue='YES Transition',size='YES Transition',sizes=(500,500)
           , alpha=.5, palette="muted",
            height=10,length=10,data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b40fbb1ae708> in <module>
#       8 sns.relplot(x="Race (2018 Std.)", y='Treatment LOS', hue='YES Transition',size='YES Transition',sizes=(500,500)
#       9            , alpha=.5, palette="muted",
# ---> 10             height=10,length=10,data=df)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1611     g.map_dataframe(func, x, y,
#    1612                     hue=hue, size=size, style=style,
# -> 1613                     **plot_kws)
#    1614
#    1615     # Show the legend
#
# ...

# %%
df['Age 1st Arrest'].value_counts()
# Out:
# 0     880
# 15    517
# 14    517
# 13    434
# 16    354
# 12    209
# 17     89
# 11     82
# 10     36
# 9      20
# 8       8
# 18      5
# 19      1
# 20      1
# Name: Age 1st Arrest, dtype: int64

# %%
df['Committed less than 6 months'].value_counts()
# Out:
# No     2695
# Yes     458
# Name: Committed less than 6 months, dtype: int64

# %%
df['Committed less than 6 months'].value_counts()
# Out:
# No     2695
# Yes     458
# Name: Committed less than 6 months, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Yes', 'No'
sizes = [458,2695]
colors = ['gold',  'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Committed less than 6 months')
plt.axis('equal')
plt.show()

# %%
plot_test=df['Age 1st Arrest'].hist(by=df['Committed less than 6 months'],sharex=True,bins=10)

# %%
plot_test=df['Age 1st Arrest'].hist(by=df['YES Transition'],sharex=True,bins=10)

# %%
import seaborn as sns

sns.barplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=df, saturation=0.8)

# %%
import seaborn as sns

sns.scatterplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=df)

# %%
import seaborn as sns
sns.pointplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=df,size=150)

# %%
df=df.

# %%
import seaborn as sns
sns.catplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=df,kind='box')

# %%
import seaborn as sns
sns.catplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=df,kind='swarm')

# %%
g = sns.catplot(x="Age 1st Arrest", y="Committed less than 6 months", row="YES Transition",
                kind="box", orient="h", height=2, aspect=6,
                data=new_df)
g.set(xscale="log");

# %%
import seaborn as sns
sns.catplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=new_df,kind='swarm')

# %%
import seaborn as sns
sns.catplot(x='Age 1st Arrest', y='Committed less than 6 months', hue='YES Transition', data=new_df,kind='box')

# %%
index_new=df[df['Age 1st Arrest']==0].index

# %%
new_df=df[df["Age 1st Arrest"] != 0]

# %%
g = sns.catplot(x="Committed less than 6 months", y="Age 1st Arrest",
                hue="YES Transition",
                data=df, kind="point",
                dodge=True,
                height=4, aspect=.7);

# %%
import seaborn as sns
sns.countplot(x='test_value', hue='Result',data=data)

# %%
import seaborn as sns, numpy as np, pandas as pd, random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid", {'axes.grid' : False})

fig = plt.figure(figsize=(6,6))

ax = Axes3D(fig)

x=df['Age 1st Arrest']
y=df['Committed less than 6 months']
z=df['YES Transition']


g = ax.scatter(x, y, z, c=x, marker='o', depthshade=False, cmap='Paired')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# produce a legend with the unique colors from the scatter
legend = ax.legend(*g.legend_elements(), loc="lower center", title="X Values", borderaxespad=-10, ncol=4)
ax.add_artist(legend)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-30722b1a8686> in <module>
#      13
#      14
# ---> 15 g = ax.scatter(x, y, z, c=x, marker='o', depthshade=False, cmap='Paired')
#      16 ax.set_xlabel('X Label')
#      17 ax.set_ylabel('Y Label')
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2356             self.set_zmargin(0.05)
#    2357
# -> 2358         self.auto_scale_xyz(xs, ys, zs, had_data)
#    2359
#    2360         return patches
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     496         Y = np.reshape(Y, -1)
#     497         self.xy_dataLim.update_from_data_xy(
# --> 498             np.column_stack([X, Y]), not had_data)
#     499         if Z is not None:
# ...

# %%
sns.distplot(df.loc[df['Committed less than 6 months'] == 'Yes']['Age 1st Arrest'])
sns.distplot(df.loc[df['Committed less than 6 months'] == 'No']['Age 1st Arrest']);

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df['YES Transition'].value_counts()
# Out:
# No     1824
# Yes    1329
# Name: YES Transition, dtype: int64

# %%
df1=df.loc[df['YES Transition'] == 'YES']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 79 columns):
# Unnamed: 0                              0 non-null int64
# MID                                     0 non-null int64
# Age at Discharge                        0 non-null int64
# Initial Commitment                      0 non-null object
# Current  Commitment Date                0 non-null object
# Age at Initial Commit                   0 non-null int64
# c1yr                                    0 non-null object
# Age 1st Arrest                          0 non-null int64
# CW at YES start                         0 non-null object
# Placement at YES                        0 non-null object
# Sub-placement at YES                    0 non-null object
# MSO Code                                0 non-null object
# Recent YLS Norm at Y.E.S.               0 non-null object
# YES Start Date                          0 non-null object
# Discharge Date = YES Start Date         0 non-null object
# ...

# %%
df1['Committed less than 6 months'].value_counts()
# Out:
# Series([], Name: Committed less than 6 months, dtype: int64)

# %%
df2=df.loc[df['YES Transition'] == 'NO']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 79 columns):
# Unnamed: 0                              0 non-null int64
# MID                                     0 non-null int64
# Age at Discharge                        0 non-null int64
# Initial Commitment                      0 non-null object
# Current  Commitment Date                0 non-null object
# Age at Initial Commit                   0 non-null int64
# c1yr                                    0 non-null object
# Age 1st Arrest                          0 non-null int64
# CW at YES start                         0 non-null object
# Placement at YES                        0 non-null object
# Sub-placement at YES                    0 non-null object
# MSO Code                                0 non-null object
# Recent YLS Norm at Y.E.S.               0 non-null object
# YES Start Date                          0 non-null object
# Discharge Date = YES Start Date         0 non-null object
# ...
